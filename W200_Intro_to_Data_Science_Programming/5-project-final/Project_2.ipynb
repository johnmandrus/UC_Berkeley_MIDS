# %%
import csv
import pandas as pd

csv_data_read = open('old_osha.csv', 'rt')
old_osha = list(csv.reader(csv_data_read))
csv_data_read.close()
#print(old_osha[2:5],'\n\n')

csv_data_read = open('new_osha.csv', 'rt')
new_osha = list(csv.reader(csv_data_read))
csv_data_read.close()
#print(new_osha[0:3], '\n\n')


states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

columns = ['Year','Month','Day','City','State','Zip','Event Description',]
osha = []

for i in range(1,100):
    
    split_date = new_osha[i][0].split('/')
    #print(split_date)
    
    m = split_date[0]
    d = split_date[1]
    y = split_date[2]
    
    state = new_osha[i][2]
    city = new_osha[i][1]
    ed = new_osha[i][3]
    
    z = ''
    
    #print([y,m,d,state,city,z,ed])
    osha.append([y,m,d,state,city,z,ed])
    
for i in range(2,5387):
    row = []
    m = ''
    y = ''
    d = ''
    ed = ''
    z = ''
    s = ''
    c = ''
    
    split_date = old_osha[i][0].split('/')
    #print(split_date)
    
    m = split_date[0]
    d = split_date[1]
    y = split_date[2]
    ed = old_osha[i][3]
    
    split_loc = old_osha[i][1].split(',')
    split_cs = split_loc[len(split_loc)-1].split()
    #print(split_cs)
    
    for j in range(len(split_cs)-1, 0,-1):
        #print(j)
        if len(split_cs[j]) == 5 and split_cs[j].isnumeric():
            z = split_cs[j]
        if split_cs[j] in states:
            s = split_cs[j]
    
    row = [y,m,d,s,c,z,ed]
    print(row)
    osha.append(row)
    
#print(osha[75:125])
# Out:
# ['2017', '4', '28', 'FL', '', '33324', 'A worker died after being caught between two vehicles. ']
# ['2017', '4', '27', 'TX', '', '79602', 'Worker fatally injured in fall from roof. ']
# ['2017', '4', '27', 'NY', '', '10038', 'A worker died after falling from a 6 foot ladder. ']
# ['2017', '4', '27', 'AL', '', '35244', 'Worker struck and killed by log. ']
# ['2017', '4', '26', 'OH', '', '45011', 'Worker died after being struck by a front end loader.']
# ['2017', '4', '26', 'KS', '', '66086', 'Worker fatally injured in fall from roof. ']
# ['2017', '4', '25', 'OH', '', '44846', 'Worker fatally injured in fall when fuel truck exploded.']
# ['2017', '4', '25', 'GA', '', '30080', 'One worker died and another hospitalized after being ejected from bucket. ']
# ['2017', '4', '25', 'FL', '', '12101', 'Worker died after being electrocuted. ']
# ['2017', '4', '25', 'FL', '', '33904', 'Worker died after being electrocuted.']
# ['2017', '4', '24', '', '', '', 'Worker fatally struck by vehicle.']
# ['2017', '4', '24', 'TX', '', '75201', 'One worker fatally injured and another hospitalized in crane collapse.']
# ['2017', '4', '24', 'IL', '', '62401', 'Worker died after falling from ladder. ']
# ['2017', '4', '24', 'GA', '', '30034', 'Worker died after being electrocuted. ']
# ['2017', '4', '22', 'IA', '', '52632', 'Worker drowned when cart fell into damn. ']
# ['2017', '4', '22', '', '', '98365', 'Worker died after falling on asphalt mixing conveyor and  stairway.  ']
# ['2017', '4', '21', 'TX', '', '75401', 'Worker fatally injured in fall from top of  grain silo. ']
# ['2017', '4', '20', '', '', '47374', 'Worker fatally injured after being thrown out of bucket truck.']
# ['2017', '4', '20', 'GA', '', '30542', 'Worker fatally injured when wall collapsed.  ']
# ['2017', '4', '20', 'LA', '', '77571', 'Worker crushed crane and container.']
# ['2017', '4', '20', 'PA', '', '15213', 'Worker died after being electrocuted. ']
# ['2017', '4', '20', '', '', '24019', 'Worker performing building demolishion killed when walls and roof collapsed.  ']
# ['2017', '4', '19', 'TX', '', '79084', 'Worker struck and killed by ATV.']
# ['2017', '4', '19', 'WI', '', '53204', 'Worker died in 20 foot fall to ground.']
# ['2017', '4', '18', 'NY', '', '14092', 'Worker crushed between arial lift basket and roof.']
# ['2017', '4', '18', 'FL', '', '33634', 'Worker fatally injured after falling from a 2 foot high loading platform.  ']
# ['2017', '4', '18', 'AR', '', '72476', 'Worker struck and killed by maintenance truck. ']
# ['2017', '4', '18', 'PA', '', '18702', 'Worker died after falling from pick-up truck.']
# ['2017', '4', '18', '', '', '05363', 'Worker electrocuted when crane contacted high voltage line.']
# ['2017', '4', '18', 'LA', '', '71052', 'One worker died and another hospitalized in oil tak explosion.']
# ['2017', '4', '18', 'TX', '', '79336', 'Worker performing welding died in fall to concrete floor. ']
# ['2017', '4', '17', 'TX', '', '75672', 'Worker died from burns suffered while performing maintenance on a limit switch.  ']
# ['2017', '4', '17', 'MT', '', '59047', 'Worker struck and killed by truck. ']
# ['2017', '4', '15', '', '', '95383', 'Worker cutting tree top fatally injured injured in fall.']
# ['2017', '4', '15', '', '', '42452', 'Worker struck and killed by  semi-trailer.']
# ['2017', '4', '15', 'TX', '', '78113', 'Worker suffered fatal head injuries in trench collapse.']
# ['2017', '4', '14', 'FL', '', '34654', 'Worker died after being run over by a dump truck. ']
# ['2017', '4', '14', 'IL', '', '60431', 'Worker fatally injured while using a chainsaw.   ']
# ['2017', '4', '13', 'MA', '', '02062', 'Worker died after falling onto concrete floor.']
# ['2017', '4', '13', '', '', '50158', 'Worker checking air tank for leaks when struck and killed by piping plug.']
# ['2017', '4', '13', 'NY', '', '12572', 'Worker died after being struck by bulldozer. ']
# ['2017', '4', '13', '', '', '37037', 'Worker installing road signs struck and killed by vehicle.']
# ['2017', '4', '13', 'NY', '', '11771', 'Worker performing external brick work died in fall from scaffold.']
# ['2017', '4', '12', 'FL', '', '33498', 'Worker fatally injured in fall from overpass. ']
# ['2017', '4', '12', '', '', '37210', 'Worker was struck by baler door. ']
# ['2017', '4', '12', 'TX', '', '75159', 'Worker suffered fatal head injuries in fall from ladder. ']
# ['2017', '4', '12', '', '', '20748', 'Worker fatally injured in fall from tree during felling operations.']
# ['2017', '4', '12', 'NY', '', '10019', 'Worker died after falling 18 feet to the floor.  ']
# ['2017', '4', '12', '', '', '89119', 'Worker fatally injured in fall from residential roof.']
# ['2017', '4', '11', 'LA', '', '70363', 'Worker died after being electrocuted. ']
# ['2017', '4', '11', 'MO', '', '64056', 'Worker died after explosion at ammunition plant.']
# ['2017', '4', '11', '', '', '48348', 'Worker killed in fall from residential roof.Â\xa0 ']
# ['2017', '4', '11', '', '', '98065', 'Worker struck and killed by tree stumps being pulled from the ground.']
# ['2017', '4', '10', 'NY', '', '11237', 'Worker struck and killed by truck while loading materials.']
# ['2017', '4', '10', 'OH', '', '43968', 'Worker crushed when truck rolled over. ']
# ['2017', '4', '10', '', '', '37095', 'Worker fatally injurd after being pinned under tree.']
# ['2017', '4', '10', 'MS', '', '39210', 'Worker suffered fatal head injuries after tripping and falling.']
# ['2017', '4', '10', 'OH', '', '45240', ' Worker fatally crushed between coils.']
# ['2017', '4', '10', 'TX', '', '77494', 'Worker died after being caught between bulldozer and storage container.']
# ['2017', '4', '9', 'CO', '', '80921', 'Worker died after falling through open hole onto concrete.   ']
# ['2017', '4', '8', '', '', '48220', 'Worker struck and killed by wood siding.']
# ['2017', '4', '8', 'FL', '', '33196', 'Worker struck and killed by vehicle']
# ['2017', '4', '8', 'FL', '', '33023', 'Worker struck and killed by 18 wheeler. ']
# ['2017', '4', '8', '', '', '98520', 'Worker fatally injured in fall from platform.']
# ['2017', '4', '8', 'WV', '', '26726', 'Worker fatally injured after being pulled into wood chip pile chain conveyor system,.']
# ['2017', '4', '7', 'OR', '', '97019', 'Worker died when boat capsized.']
# ['2017', '4', '7', '', '', '48446', 'Worker performing welding fatally crushed when a 3,000 lb. part mounted on a fixture when part fell.']
# ['2017', '4', '7', 'GA', '', '30180', 'One worker died and two others hospitalized after being struck by an automobile while dismantling highway work zone safety devices.']
# ['2017', '4', '6', '', '', '98901', 'Worker shot and killed during store robbery.']
# ['2017', '4', '6', '', '', '37027', 'Worker struck and killed by material that fell from trailer.  ']
# ['2017', '4', '6', '', '', '95246', 'Worker struck and killed by falling tree branch.']
# ['2017', '4', '6', 'IL', '', '61727', 'Worker fatally crushed by a load of steel sheets. ']
# ['2017', '4', '6', 'TX', '', '77437', 'One worker died and another hospitalized after being crushed by  bucket of a front loader. ']
# ['2017', '4', '5', 'ID', '', '83301', 'Worker fatally crushed by compactor plate. ']
# ['2017', '4', '5', 'LA', '', '70669', 'Worker died in fall from scaffold.']
# ['2017', '4', '5', '', '', '93902', 'Worker fatally injured after becoming caught and pulled into onion/leek processing line machine.']
# ['2017', '4', '4', 'GA', '', '30549', 'Worker fatally injured in fall onto concrete.']
# ['2017', '4', '4', '', '', '52807', 'Road crew worker fatally injured when vehicled collided with oncoming traffic. ']
# ['2017', '4', '4', 'MS', '', '39648', 'Worker died after being electrocuted. ']
# ['2017', '4', '4', '', '', '41042', 'Worker suffered fatal injuries in motor vehicle accident. ']
# ['2017', '4', '3', 'WI', '', '53597', 'Worker died from carbon monoxide exposure while operating a gas powered pressure washer. ']
# ['2017', '4', '3', 'GA', '', '30224', 'Worker died after tripping and falling.']
# ['2017', '4', '3', 'TX', '', '76034', 'Worker died after being electrocuted. ']
# ['2017', '4', '3', 'MO', '', '63104', 'Worker fatally injured when boiler exploded.']
# ['2017', '4', '3', '', '', '85233', 'Worker struck and killed by load that fell from forklift.']
# ['2017', '4', '3', 'CO', '', '80210', 'Worker fatally injured after falling from balcony.  ']
# ['2017', '4', '1', 'GA', '', '31046', 'Worker fatally injured after being struck by chain. ']
# ['2017', '4', '1', 'FL', '', '34639', 'Worker died from burns while repairing bread oven.']
# ['2017', '4', '1', 'TX', '', '77007', 'Worker electrocuted while removing lighting fixtures and electrical wires. ']
# ['2017', '3', '31', 'GA', '', '30297', 'Worker died after being thrown from forklift. ']
# ['2017', '3', '30', 'TX', '', '77550', 'Worker replacing cable wires fatally injured in fall. ']
# ['2017', '3', '30', '', '', '21032', 'Worker in bucket truck electrocuted after contacting power line.']
# ['2017', '3', '30', 'OH', '', '43021', 'Worker struck and killed by steel beam. ']
# ['2017', '3', '30', 'GA', '', '30263', 'Worker died after being crushed by pipe bore casing.']
# ['2017', '3', '29', '', '', '91735', 'Worker struck and killed by excavator.']
# ['2017', '3', '29', 'IL', '', '60047', 'Worker struck and killed by paver machine. ']
# ['2017', '3', '29', 'ND', '', '58201', 'Worker electrocuted while remodeling kitchen.']
# ['2017', '3', '29', 'TX', '', '79835', 'Worker electrocuted after contacting high voltage box. ']
# ['2017', '3', '28', '', '', '40212', 'Worker suffered fatal injuries in motor vehicle accident.  ']
# ['2017', '3', '27', 'PA', '', '19095', 'A worker died after being crushed by an overturned box. ']
# ['2017', '3', '27', 'TX', '', '79770', 'A worker died after being entangled by an agitator machine.  ']
# ['2017', '3', '27', '', '', '', 'Worker fatally injured after being thrown when gas tank rapidly depressurized.']
# ['2017', '3', '27', 'TX', '', '75964', 'Worker struck and killed by forklift.']
# ['2017', '3', '25', 'LA', '', '70723', 'Worker fatally injured after falling from barge into river.']
# ['2017', '3', '24', 'IL', '', '60043', 'Worker suffered fatal injuries in fall down stairs.']
# ['2017', '3', '23', 'LA', '', '70611', ' Worker struck and killed when a boom on a truck broke lose. \n']
# ['2017', '3', '23', 'WI', '', '54401', 'Worker fatally injured in fall from step ladder. ']
# ['2017', '3', '23', 'MA', '', '02451', 'Worker fatally injured in fall from ladder jack scaffold.   ']
# ['2017', '3', '23', '', '', '48125', 'Worker repair road struck and killed by truck.']
# ['2017', '3', '22', 'FL', '', '33413', 'Roadway worker struck and killed by vehicle.']
# ['2017', '3', '22', 'NY', '', '14606', 'Worker fatally crushed by 900 pound bale of material.']
# ['2017', '3', '22', '', '', '96950', 'Worker died died in fall from scaffold.']
# ['2017', '3', '22', '', '', '55125', 'Worker fatally injured after becaming entangled in sewer lining equipment.']
# ['2017', '3', '21', 'MA', '', '01970', 'Worker in aerial lift electrocuted after contacting power line.  ']
# ['2017', '3', '21', '', '', '40014', 'Worker performing vinyl siding work fatally injured in fall  from roof.']
# ['2017', '3', '21', 'WI', '', '53129', ' Worker suffered fatal injuries after being struck by boxes while unloading a trailer.']
# ['2017', '3', '20', 'NE', '', '68528', 'Worker fatally injured in fall down stairs.']
# ['2017', '3', '18', '', '', '', 'Worker fatally injured in fall.']
# ['2017', '3', '17', 'NY', '', '11430', 'Worker fatally injured in fall from aircraft.']
# ['2017', '3', '16', 'KS', '', '67801', 'Worker fatally injured in fall from roof. ']
# ['2017', '3', '16', '', '', '91766', 'Worker killed in fall while trimming tree.']
# ['2017', '3', '16', 'AL', '', '36065', 'Worker struck and killed by vehicle while working on a bridge project.  ']
# ['2017', '3', '16', '', '', '37129', 'Worker fatally injured after being pulled into conveyor belt pulley.  ']
# ['2017', '3', '16', '', '', '95328', 'Worker was unloading his truck when struck by a train.']
# ['2017', '3', '16', 'TX', '', '78040', 'Worker electrocuted after contacting power line.']
# ['2017', '3', '16', '', '', '95203', 'Worker was directing traffic at dump site when struck by a vehicle.']
# ['2017', '3', '15', 'TX', '', '76377', ' Worker crushed when oncrete footing collapsed.']
# ['2017', '3', '15', '', '', '40379', 'Worker fatally injured in scaffold collapse.']
# ['2017', '3', '15', 'NY', '', '11714', 'Worker fatally injured in fall from scaffold.']
# ['2017', '3', '14', 'KS', '', '66601', 'Stock room worker fatally injured in fall. ']
# ['2017', '3', '14', 'TX', '', '77511', 'Worker stuck and killed by derrick.']
# ['2017', '3', '14', 'FL', '', '33126', 'Worker struck and killed by tug boat. ']
# ['2017', '3', '13', 'IL', '', '60827', 'Worker suffered fatal injuries after being struck by crane.\n']
# ['2017', '3', '13', '', '', '95948', 'Worker fatally injured in tractor roll over.']
# ['2017', '3', '13', 'TX', '', '75189', 'Worker fatally injured after being pinned between steel beams. ']
# ['2017', '3', '12', '', '', '93307', 'Worker fatally injured after being trapped in palm tree fronds.']
# ['2017', '3', '10', '', '', '85015', 'Worker killed in fall.']
# ['2017', '3', '10', '', '', '52247', 'Worker suffered fatal injured after being struck by lifting device. ']
# ['2017', '3', '10', 'MO', '', '64120', 'Worker suffered broken leg in fall and later died from complications during surgery.']
# ['2017', '3', '10', 'NY', '', '10314', 'Worker struck and killed by conveyor equipment.']
# ['2017', '3', '10', 'CA', '', '94520', 'Worker electrocuted after contacting transformer.\n']
# ['2017', '3', '9', 'NJ', '', '07002', 'Worked fatally injured when boat collided with a buoy.']
# ['2017', '3', '9', 'TX', '', '78251', 'Worker killed in trench collapse.  ']
# ['2017', '3', '9', 'FL', '', '34448', 'Worker performing tree trimming suffered fatal injuries after being pulled to the ground when tie off ropes were pulled into chipper.']
# ['2017', '3', '8', '', '', '', 'Worker crushed between trailer and tire.']
# ['2017', '3', '8', '', '', '90265', 'Worker died in fall from ladder.']
# ['2017', '3', '8', '', '', '56331', 'Worker drowned when skid loader broke through ice.']
# ['2017', '3', '8', 'FL', '', '32723', 'Worker killed in fall from roof.']
# ['2017', '3', '7', 'FL', '', '33446', 'Worker preparing to peform exterior painting fatally injured in fall.  ']
# ['2017', '3', '7', '', '', '48601', 'Worker struck and killed by furnace door.']
# ['2017', '3', '7', 'AL', '', '36421', 'Worker died of sepsis after his arm was cut in a machine.']
# ['2017', '3', '6', 'TX', '', '79855', 'Two highway workers struck and killed by tractor trailer. A third worker was hospitalized.']
# ['2017', '3', '6', 'TX', '', '75007', 'Worker struck and killed by vehicle at construction site.']
# ['2017', '3', '6', '', '', '92240', 'Worker fatally injured when high pressure valve exploded.']
# ['2017', '3', '6', '', '', '92337', 'Worker died in fall from ladder.']
# ['2017', '3', '5', 'IL', '', '62040', 'Worker suffered fatal injuries in fall from rail car.']
# ['2017', '3', '3', 'IL', '', '61109', 'Worker fatally injured in fall on stairs.']
# ['2017', '3', '3', 'ME', '', '04947', 'Worker died in fall while preparing ski course.']
# ['2017', '3', '2', 'TX', '', '79706', 'Worker struck and killed by forklift.']
# ['2017', '3', '2', 'WI', '', '54313', 'Worker fatally crushed between two trucks.']
# ['2017', '3', '2', 'FL', '', '33908', 'Worker died while performing trimming tree services.']
# ['2017', '3', '1', '', '', '99323', 'Worker struck and killed by equipment while removing axle from a trailer.']
# ['2017', '3', '1', '', '', '89052', 'Worker died after falling through floor opening.']
# ['2017', '3', '1', 'NJ', '', '07470', 'Worker died while performing maintenance on concrete truck.']
# ['2017', '2', '28', 'DC', '', '20007', 'Worker died in trench collapse.']
# ['2017', '2', '28', 'ND', '', '58103', 'Worker fatally crushed between vehicle and building.']
# ['2017', '2', '28', 'NY', '', '12052', 'Worker died while installing plywood decking.']
# ['2017', '2', '28', 'IL', '', '60538', 'Worker died in fall.']
# ['2017', '2', '28', 'MA', '', '01720', 'Worker struck and killed by car.']
# ['2017', '2', '27', 'FL', '', '33328', ' Worker struck and killed by vehicle']
# ['2017', '2', '27', '', '', '52627', 'Worker died after falling from of back of truck.']
# ['2017', '2', '17', '', '', '40204', 'Worker fatally stabbed.']
# ['2017', '2', '17', '', '', '89054', 'Worker killed in vehicle explosion.']
# ['2017', '2', '16', '', '', '91335', 'Worker dies in fall from scaffold.']
# ['2017', '2', '11', 'MO', '', '65608', 'Worker died in fall from tree.']
# ['2017', '2', '11', 'RI', '', '02886', 'Worker died after being struck by front end loader.']
# ['2017', '2', '10', 'OK', '', '73107', 'Worker died after being struck by vehicle.']
# ['2017', '2', '10', 'MS', '', '38617', 'Two workers drowned in lake while fishing. ']
# ['2017', '2', '10', 'NY', '', '10128', 'Worker died in fall through glass window.  ']
# ['2017', '2', '10', 'TX', '', '75019', 'Worker died after being struck by winch.']
# ['2017', '2', '9', '', '', '95076', 'Worker died after being struck by truck.']
# ['2017', '2', '9', 'LA', '', '70080', 'Worker died in pipeline explosion. ']
# ['2017', '2', '8', 'PA', '', '15846', 'Worker died after being buried in landfill collapse. ']
# ['2017', '2', '8', 'FL', '', '33125', 'One worker died and another was hospitalized after train struck aerial lift.']
# ['2017', '2', '8', 'LA', '', '70634', 'Three workers died after pressurized tank exploded.']
# ['2017', '2', '8', 'WV', '', '25045', 'Worker died after being struck by falling branch. ']
# ['2017', '2', '8', 'TX', '', '78209', 'Worker died in fall. ']
# ['2017', '2', '8', 'IL', '', '60622', 'Worker fatally crushed between stone polishing machine and wall. ']
# ['2017', '2', '6', '', '', '90810', 'Worker died in fall from scissor lift.']
# ['2017', '2', '6', 'NY', '', '12491', 'Worker died after being caught in wood splitting machine.']
# ['2017', '2', '6', 'MN', '', '55807', 'Worker died from burns suffered while performing hot work.  ']
# ['2017', '2', '6', 'LA', '', '70510', 'Worker died after being struck by hydraulic cylinder.  ']
# ['2017', '2', '4', 'IL', '', '60614', 'Worker died after being struck by falling brick.']
# ['2017', '2', '3', 'TX', '', '78207', 'Worker asphyxiated in crawl space while unclogging drains. ']
# ['2017', '2', '3', '', '', '91362', 'Worker died from carbon monoxide poisoning.']
# ['2017', '2', '3', 'TX', '', '79838', 'Worker died after being struck by tree branch. ']
# ['2017', '2', '3', 'IL', '', '60134', 'Worker fatally crushed between aerial lift and tower. ']
# ['2017', '2', '3', 'AL', '', '36105', 'Worker died from exposure to gas in sewer line. ']
# ['2017', '2', '2', 'TX', '', '79360', 'Worker died in fall from substructure.']
# ['2017', '2', '2', 'LA', '', '70129', 'Worker died in fall through floor opening.']
# ['2017', '2', '2', 'FL', '', '34689', 'Worker died in fall.']
# ['2017', '2', '2', '', '', '37115', 'Worker drowned while trying to rescue driver from vehicle in river.']
# ['2017', '2', '1', '', '', '48529', 'Worker died when tire exploded.']
# ['2017', '2', '1', 'MO', '', '64068', 'Worker suffocated inside truck tank. ']
# ['2017', '2', '1', 'CO', '', '80206', 'Worker died in fall at construction site.']
# ['2017', '1', '31', 'TX', '', '75201', 'Worker died in fall from scaffold.']
# ['2017', '1', '31', 'FL', '', '33170', 'Worker died in fall.']
# ['2017', '1', '31', 'DE', '', '19939', 'Worker died in fall from building.']
# ['2017', '1', '31', 'TX', '', '77585', 'Worker died in fall.']
# ['2017', '1', '30', 'PA', '', '17058', 'Worker died after falling from upper level of home. ']
# ['2017', '1', '30', '', '', '46802', 'Worker died after falling from dumpster.']
# ['2017', '1', '29', 'TX', '', '77380', 'Worker washing windows died in fall.']
# ['2017', '1', '26', 'OH', '', '45885', 'Worker died after being struck by drive motor. ']
# ['2017', '1', '25', 'NY', '', '14480', 'A worker died after being engulfed by fertilizer.  ']
# ['2017', '1', '25', 'VA', '', '24502', 'Worker died in fall after receiving electrical shock.']
# ['2017', '1', '25', 'PA', '', '17404', 'Worker died in fall from roof. ']
# ['2017', '1', '25', 'FL', '', '33196', 'Worker fatally crushed by hauler.']
# ['2017', '1', '24', '', '', '37013', 'Worker died in fall from roof.']
# ['2017', '1', '24', '', '', '88220', 'Worker died in vehicle collision.']
# ['2017', '1', '24', 'FL', '', '32162', 'Worker died in fall from roof.']
# ['2017', '1', '24', '', '', '96146', 'Worker died in explosion during avalanche control blasting.']
# ['2017', '1', '24', 'MA', '', '02702', 'Worker fatally crushed beneath pallet jack.']
# ['2017', '1', '23', 'TX', '', '77007', 'Worker died in fall down stairwell.']
# ['2017', '1', '23', 'WI', '', '54846', 'Worker died after being struck by falling tree. ']
# ['2017', '1', '23', 'TN', '', '38468', 'Three workers hositalized for burns following a natural gas explosion.']
# ['2017', '1', '23', '', '', '20707', 'Worker fatally crushed between vehicle and garbage truck.']
# ['2017', '1', '23', '', '', '91710', 'Worker died in fall through skylight.']
# ['2017', '1', '23', 'TX', '', '78245', 'Worker died after being struck by bucket.']
# ['2017', '1', '22', 'OK', '', '73932', 'One worker died and another was hospitalized after contacting power line. ']
# ['2017', '1', '21', 'TX', '', '79101', 'One worker died and another was hospitalized from arcc flash in electrical room.']
# ['2017', '1', '21', '', '', '89014', 'Worker fatally shot by security guard during armed robbery.']
# ['2017', '1', '20', 'TX', '', '78717', 'Worker died after being struck by crawler dozer.']
# ['2017', '1', '20', '', '', '04107', 'Worker died after being struck by a motor vehicle.']
# ['2017', '1', '19', 'FL', '', '32962', 'Worker died after being struck by vehicle. ']
# ['2017', '1', '19', 'NJ', '', '08080', 'Worker fatally crushed between granite slabs. ']
# ['2017', '1', '19', '', '', '93722', 'Worker asphyxiated while cleaning waste.']
# ['2017', '1', '18', '', '', '37302', 'Worker died after falling off bluff. ']
# ['2017', '1', '18', 'AL', '', '36426', 'Worker died after being struck by tree.']
# ['2017', '1', '18', 'PA', '', '17264', 'Worker died after being struck by tree.']
# ['2017', '1', '18', '', '', '95202', 'Worker died in fall from roof.']
# ['2017', '1', '18', 'DC', '', '20005', 'Worker died in fall from scaffold.']
# ['2017', '1', '18', 'SD', '', '57058', 'Worker died in fall from roof.']
# ['2017', '1', '17', '', '', '96913', 'Worker died after being struck by vehicle. ']
# ['2017', '1', '17', 'MA', '', '01527', 'Worker died in fall from roof.']
# ['2017', '1', '17', '', '', '91605', 'Worker fatally crushed between mechanical loading dock.']
# ['2017', '1', '16', 'FL', '', '33037', 'Three workers died from exposure to fumes inside storm drain.']
# ['2017', '1', '16', 'PA', '', '19020', 'Worker fatally crushed by beam.  ']
# ['2017', '1', '15', 'PA', '', '16365', 'Worker died after being struck by vehicle. ']
# ['2017', '1', '15', '', '', '98682', 'Worker died from smoke inhalation.']
# ['2017', '1', '15', 'WI', '', '54401', 'Worker died after being struck by steel girder. ']
# ['2017', '1', '14', '', '', '46229', 'Two workers fatally shot by unknown assailant. ']
# ['2017', '1', '14', '', '', '96799', 'Three workers died and another hospitalized after crane contacted overhead powerline.']
# ['2017', '1', '13', 'FL', '', '33139', 'Worker died in fall from scaffold.']
# ['2017', '1', '13', '', '', '40502', 'Worker died after falling through hole in roof.']
# ['2017', '1', '13', 'IL', '', '60403', 'Worler died in fall from container. ']
# ['2017', '1', '13', '', '', '92239', 'Worker died after being struck by bucket of backhoe.']
# ['2017', '1', '12', '', '', '', 'Worker died in fall through skylight.']
# ['2017', '1', '12', 'TX', '', '79706', 'Worker died after being found unresponsive inside FRAC tank.']
# ['2017', '1', '12', 'FL', '', '34292', 'Worker died after being struck by tree limb.']
# ['2017', '1', '12', 'MO', '', '63801', 'Worker fatally crushed between mast and body of truck. ']
# ['2017', '1', '12', '', '', '', 'Worker died in fall at residential construction site.']
# ['2017', '1', '12', 'FL', '', '33166', 'Worker drowned while performing commercial diving.']
# ['2017', '1', '12', 'IL', '', '60446', 'Worker died after being struck by falling automotive products. ']
# ['2017', '1', '12', '', '', '75001', 'Worker died after being struck by vehicle.']
# ['2017', '1', '12', 'WV', '', '26149', 'Worker fatally crushed between tractor trailer and silo.  ']
# ['2017', '1', '11', 'OK', '', '73036', 'Worker died after being struck by a forklift. ']
# ['2017', '1', '11', '', '', '48120', 'Worker inspecting crane died in fall when walkway collapsed.']
# ['2017', '1', '10', 'FL', '', '34711', 'Worker died in fall. ']
# ['2017', '1', '10', '', '', '95252', 'Worker drowned when ATV entered water.']
# ['2017', '1', '10', '', '', '21122', 'Worker performing flagging activities in work zone died after being struck by vehicle.']
# ['2017', '1', '10', '', '', '98421', 'Worker fatally crushed between two trailers.']
# ['2017', '1', '9', 'FL', '', '33411', 'Worker electrocuted when forklift contacted energized cable.']
# ['2017', '1', '9', 'TX', '', '78006', 'Worker died after being struck by truck. ']
# ['2017', '1', '7', '', '', '05751', 'Worker died in fall through hole in floor of ski gondola.']
# ['2017', '1', '7', '', '', '96130', 'Worker died after being struck by semi-truck.']
# ['2017', '1', '6', '', '', '42053', 'Worker electrocuted after contacting power lines.']
# ['2017', '1', '6', 'PA', '', '18015', 'Worker killed in fall through floor opening.']
# ['2017', '1', '6', '', '', '89014', 'Worker died in fall from roof.']
# ['2017', '1', '6', 'FL', '', '34480', 'Worker killed in fall through floor opening.']
# ['2017', '1', '6', '', '', '91024', 'Worker killed in fall from tree.']
# ['2017', '1', '5', 'TX', '', '75141', 'Worker struck and killed by truck.']
# ['2017', '1', '5', 'GA', '', '30809', 'Worker killed in trench collapse.']
# ['2017', '1', '5', 'TX', '', '77026', 'Worker killed in fall from skylight.']
# ['2017', '1', '5', '', '', '', 'Worker fatally crushed by trailer.']
# ['2017', '1', '4', 'ND', '', '58622', 'Worker killed in oil field explosion/fire.']
# ['2017', '1', '4', '', '', '95134', 'Worker died after striking head in fall fom chair.']
# ['2017', '1', '4', '', '', '38372', 'Worker killed when vehicle overturned.']
# ['2017', '1', '4', 'TX', '', '79546', 'Worler fatally crushed between two pieces of machinery.']
# ['2017', '1', '3', '', '', '84745', 'Worker died after being struck by excavator counterweight.']
# ['2017', '1', '3', '', '', '42701', 'Worker fatally stabbed by resident.']
# ['2017', '1', '3', '', '', '99362', 'Worker crushed between arm and cab of skid loader.']
# ['2017', '1', '3', 'FL', '', '32256', 'Worker killed in fall from scissor lift.']
# ['2017', '1', '3', 'TX', '', '75455', 'Worker struck and killed by truck.']
# ['2017', '1', '3', 'TX', '', '77303', 'Worlker killed in fall from tree.']
# ['2017', '1', '2', '', '', '55379', 'Worker killed in fall inside grain tank.']
# ['2016', '12', '31', 'OH', '', '45322', 'Worker killed in fall from platform.']
# ['2016', '12', '29', 'TX', '', '77041', 'Worker fatally crushed by granite slabs.']
# ['2016', '12', '29', 'TX', '', '77632', 'Two workers hospitalized after being sprayed with caustic black liquor.']
# ['2016', '12', '29', 'SD', '', '57036', 'Worker killed in fall from height.']
# ['2016', '12', '29', 'TX', '', '77040', 'Worker fatally crushed by granite slabs.']
# ['2016', '12', '29', 'WI', '', '54313', 'One worker killed and another hospitalized due to carbon monoxide poisoning.']
# ['2016', '12', '28', 'AL', '', '36732', 'Worker struck and killed by truck.']
# ['2016', '12', '28', 'FL', '', '33605', 'Worker struck and killed by front loader.']
# ['2016', '12', '28', 'GA', '', '31328', 'Worker electrocuted after falling from tree onto power lines.']
# ['2016', '12', '27', 'TX', '', '77096', 'Worker killed in fall from ladder.']
# ['2016', '12', '27', 'OH', '', '45714', 'Worker killed in fall from roof.']
# ['2016', '12', '27', '', '', '55016', 'Worker died after being struck by object while making deliveries.']
# ['2016', '12', '27', 'AR', '', '71901', 'Worker died from injuries sustained in mixing machine.']
# ['2016', '12', '24', '', '', '37601', 'Worker killed in fall through skylight.']
# ['2016', '12', '24', '', '', '37243', 'Worker directing traffic struck and killed by vehicle.']
# ['2016', '12', '23', 'NY', '', '10128', 'Worker killed in fall from height while pouring concrete floor.']
# ['2016', '12', '23', 'FL', '', '32771', 'Worker killed in fall from roof.']
# ['2016', '12', '23', 'NY', '', '11229', 'Worker struck and killed by box truck.']
# ['2016', '12', '22', '', '', '98942', 'Worker struck and killed by train.']
# ['2016', '12', '21', 'GA', '', '31206', 'Worker fatally crushed by pipes.']
# ['2016', '12', '21', '', '', '37101', 'Worker struck and killed by crane basket.']
# ['2016', '12', '21', 'TX', '', '77554', 'Worker killed in fall from roof.']
# ['2016', '12', '21', '', '', '40351', 'Worker killed in vehicle collision.']
# ['2016', '12', '21', 'AR', '', '72315', 'Worker fatally crushed between two port cars.']
# ['2016', '12', '21', 'TX', '', '76372', 'Worker struck and killed by tractor.']
# ['2016', '12', '21', 'TX', '', '77015', 'Worker struck and killed by pipe.']
# ['2016', '12', '20', 'FL', '', '32701', 'Worker struck and killed by equipment during loading.']
# ['2016', '12', '20', 'NE', '', '30121', 'Worker fatally crushed between transfer cart and doorway.']
# ['2016', '12', '19', 'WI', '', '54484', 'Worker killled in fall from height.']
# ['2016', '12', '19', 'TX', '', '78205', 'One worker killed and another hospitalized in fall from scaffold.']
# ['2016', '12', '19', 'FL', '', '33470', 'Worker drowned when front end loader toppled over into canal.']
# ['2016', '12', '18', '', '', '94607', 'Worker hospitalized after being struck by falling containers.']
# ['2016', '12', '16', 'TX', '', '76034', 'Worker struck and killed by paving roller.']
# ['2016', '12', '15', 'MO', '', '64012', 'Worker killed in trench collapsed.']
# ['2016', '12', '14', 'WI', '', '54484', 'Worker asphyxiated while welding.']
# ['2016', '12', '14', 'TX', '', '75093', 'Worker killed in fall from ladder.']
# ['2016', '12', '14', 'KS', '', '22000', 'A worker died after being run over by a pick-up truck at work.']
# ['2016', '12', '14', 'NJ', '', '07047', 'Worker fatally crushed when forklift fell from ramp.']
# ['2016', '12', '14', 'MS', '', '38722', 'Worker hospitalized after being struck by tree limb.']
# ['2016', '12', '14', '', '', '95050', 'Worker electrocuted by circuit breaker panel.']
# ['2016', '12', '14', '', '', '47711', 'Worker killed in fall in tank.']
# ['2016', '12', '14', 'GA', '', '30067', 'Worker hospitalized after being struck by car.']
# ['2016', '12', '13', 'TX', '', '77802', 'Worker hospitalized after being struck by bucket truck.']
# ['2016', '12', '13', '', '', '40175', 'Worker struck and killed by dump truck.']
# ['2016', '12', '13', 'NE', '', '68310', 'One worker killed and another hospitalized from exposure to chemical fumes.']
# ['2016', '12', '13', '', '', '85260', 'Worker killed in fall through skylight.']
# ['2016', '12', '12', '', '', '46151', 'Worker struck and killed by falling I-beam.']
# ['2016', '12', '12', 'IL', '', '60501', 'Worker struck and killed by powered industrial vehicle.']
# ['2016', '12', '12', 'FL', '', '16133', 'Worker struck and killed by front end loader.']
# ['2016', '12', '11', '', '', '96161', 'Worker killed in skiing collision.']
# ['2016', '12', '10', '', '', '55344', 'Worker struck and killed by trunk lid.']
# ['2016', '12', '10', '', '', '88012', 'Worker struck and killed by rim when tire exploded.']
# ['2016', '12', '10', '', '', '93703', 'Worker died in fall through skylight.']
# ['2016', '12', '8', 'MO', '', '63103', 'Worker struck and killed by truck when parking brake failed.']
# ['2016', '12', '8', 'NJ', '', '08816', 'Worker fatally crushed by bailing machine.']
# ['2016', '12', '7', '', '', '95974', 'Worker died from head injury after falling inside  rice silo.']
# ['2016', '12', '7', 'MO', '', '65787', 'Worker struck and killed by truck.']
# ['2016', '12', '6', '', '', '89120', 'Worker fatally crushed between crane and tree.']
# ['2016', '12', '6', 'CT', '', '06279', 'Worker fatally crushed between two trailer bodies.']
# ['2016', '12', '6', 'GA', '', '31408', 'Worker struck and killed by truck.']
# ['2016', '12', '6', '', '', '', 'Worker fatally assaulted by facility resident.']
# ['2016', '12', '5', 'TX', '', '77630', 'Worker struck and killed by forklift assembly that fell during repairs.']
# ['2016', '12', '5', 'WV', '', '25413', 'Worker killed in fall from billboard.']
# ['2016', '12', '5', 'TX', '', '77355', 'Worker electrocuted by power line while installing cable.']
# ['2016', '12', '4', 'CT', '', '06880', 'One worker killed and another hospitalized in fall from roof.']
# ['2016', '12', '4', '', '', '92373', 'Worker trimming trees died after being engulfed by palm fronds.']
# ['2016', '12', '3', '', '', '87120', 'Worker delivering pizza struck and killed by motor vehicle.']
# ['2016', '12', '3', 'NY', '', '12309', 'Worker killed in fall from roof.']
# ['2016', '12', '1', '', '', '95311', 'Worker struck and killed by tree branch.']
# ['2016', '12', '1', 'TX', '', '78245', 'Worker died after slipping on kitchen floor and striking head.']
# ['2016', '12', '1', 'PA', '', '16066', 'Worker hospitalized after fall from roof.']
# ['2016', '12', '1', 'OH', '', '43615', 'Worker killed after being caught in lathe.']
# ['2016', '12', '1', 'NY', '', '14623', 'Worker struck and killed by safety block.']
# ['2016', '12', '1', 'TX', '', '79905', 'Worker died in tank while performing abrasive blasting.']
# ['2016', '11', '30', 'MT', '', '59901', 'Worker fatally crushed by load of trusses.']
# ['2016', '11', '30', '', '', '98402', 'Worker fatally shot while responding to domestic dispute.']
# ['2016', '11', '30', 'TX', '', '79029', 'Worker struck and killed by vehicle.']
# ['2016', '11', '30', '', '', '48809', 'Worker killed in fall from articulating boom.']
# ['2016', '11', '29', '', '', '94158', 'Worker struck and killed by equipment.']
# ['2016', '11', '29', 'FL', '', '32583', 'Worker killed after being pulled into cable spool.']
# ['2016', '11', '29', '', '', '90670', 'Worker fatally crushed between crane and steel post.']
# ['2016', '11', '29', 'IL', '', '62570', 'Worker died from exposure to ethylene glycol.']
# ['2016', '11', '29', '', '', '46217', 'Worker struck and killed by motor vehicle.']
# ['2016', '11', '29', '', '', '92503', 'Worker fatally crushed between two semi trucks.']
# ['2016', '11', '28', '', '', '37701', 'Worker struck and killed by tree.']
# ['2016', '11', '28', 'MT', '', '59101', 'Worker fatally crushed by wrecker.']
# ['2016', '11', '28', 'NY', '', '11790', 'Worker killed in fall from tree.']
# ['2016', '11', '28', 'AL', '', '35453', 'Worker killed in fall from roof.']
# ['2016', '11', '27', 'OH', '', '45226', 'Worker electrocuted when ladder contacted power lines.']
# ['2016', '11', '26', 'RI', '', '02817', 'Worker killed in fall from extension ladder.']
# ['2016', '11', '25', '', '', '21111', 'Worker killed when utility vehicle flipped over.']
# ['2016', '11', '25', '', '', '55113', 'Worker struck and killed by front end loader while plowing snow.']
# ['2016', '11', '23', '', '', '24522', 'Worker killed after falling into pulping machine.']
# ['2016', '11', '23', '', '', '92882', 'Worker killed in fall from roof.']
# ['2016', '11', '23', 'NJ', '', '07501', 'Worker killed in fall from roof.']
# ['2016', '11', '22', 'NY', '', '11435', 'Two workers struck and killed by beam that broke free of crane.']
# ['2016', '11', '22', 'MA', '', '01886', 'Worker struck and killed by snow grooming machine.']
# ['2016', '11', '21', 'FL', '', '32810', 'Worker killed when articulating boom flipped.']
# ['2016', '11', '21', 'PA', '', '17573', 'Worker collecting trash struck and killed by motor vehicle.']
# ['2016', '11', '21', 'NE', '', '39647', 'Worker struck and killed by brake booster.']
# ['2016', '11', '21', '', '', '94110', 'Worker fatally crushed under forklift that fell off ramp.']
# ['2016', '11', '19', 'MA', '', '02332', 'Worker cutting pipe fatally injured by saw.']
# ['2016', '11', '18', 'NJ', '', '07440', 'Worker killed in fall from pallet on elevated forklift.']
# ['2016', '11', '18', '', '', '24224', 'Worker installing mobile home died when it fell on him.']
# ['2016', '11', '18', '', '', '52353', 'Worker fatally crushed by tailgate of dump truck.']
# ['2016', '11', '18', 'PA', '', '17815', 'Temporary worker struck and killed by baled Christmas tree.']
# ['2016', '11', '18', '', '', '84312', 'Worker directing traffic struck and killed by motor vehicle.']
# ['2016', '11', '17', 'IL', '', '61520', 'One worker killed and another hospitalized after a gas explosion.']
# ['2016', '11', '17', 'TX', '', '77049', 'Worker asphyxiated in cargo tank trailer.']
# ['2016', '11', '17', 'KS', '', '67530', 'Worker fatally crushed in plastic bottle molding machine.']
# ['2016', '11', '17', 'OH', '', '44857', 'One worker killed and two hospitalized after being struck by semi tractor trailer.']
# ['2016', '11', '17', 'MT', '', '59868', 'Worker struck and killed by unsecured load of lumber.']
# ['2016', '11', '17', 'LA', '', '71282', 'Worker fatqally engulfed by grain in elevator.']
# ['2016', '11', '16', '', '', '84025', 'Worker fatally crushed between aerial lift and steel support beam.']
# ['2016', '11', '16', '', '', '37214', 'Worker killed in fall from ladder.']
# ['2016', '11', '16', '', '', '37167', 'Worker fatally crushed by machinery.']
# ['2016', '11', '16', '', '', '', 'Worker was fatally crushed by concrete wall that collapsed during demolition.']
# ['2016', '11', '16', '', '', '92806', 'Worker struck and killed by forklift.']
# ['2016', '11', '15', '', '', '94510', 'Worker killed in fall from building under construction.']
# ['2016', '11', '15', 'WI', '', '54542', 'Worker fatally crused hydraulic log arm.']
# ['2016', '11', '14', '', '', '24251', 'Worker struck and killed by felled tree that slid down bank.']
# ['2016', '11', '13', 'WI', '', '53575', 'Worker killed when tractor rolled over.']
# ['2016', '11', '12', 'IL', '', '60087', 'Worker killed in fall through unguarded skylight.']
# ['2016', '11', '11', 'MA', '', '01930', 'Worker killed in fall on dock and into water.']
# ['2016', '11', '11', 'ND', '', '58854', 'Worker collapsed and died after loading production water at oil well site.']
# ['2016', '11', '11', 'FL', '', '32765', 'Worker killed in fall from ladder through window.']
# ['2016', '11', '10', '', '', '85201', 'Worker fatally crushed between two trucks.']
# ['2016', '11', '10', '', '', '48304', 'Worker killed in fall from tree.']
# ['2016', '11', '10', 'OH', '', '44622', 'Worker struck and killed by front end loader.']
# ['2016', '11', '10', '', '', '40229', 'Worker killed in fall through hole in roof.']
# ['2016', '11', '9', 'TX', '', '77372', 'Worker killed in fall from trailer.']
# ['2016', '11', '8', 'TX', '', '76102', 'Worker killed when fork lift flipped.']
# ['2016', '11', '8', '', '', '94577', 'Worker killed in fall from ladder.']
# ['2016', '11', '8', 'MA', '', '02125', 'Worker killed in fall from roof.']
# ['2016', '11', '8', 'FL', '', '32819', 'Worker struck and killed by robotic machine.']
# ['2016', '11', '8', 'IL', '', '61081', 'One worker was killed and another injured when bucket truck contacted power lines.']
# ['2016', '11', '7', 'PA', '', '17406', 'Worker was fatally crushed by construction pipe.']
# ['2016', '11', '7', 'WI', '', '54703', 'Worker struck and killed by semi-truck.']
# ['2016', '11', '7', 'IL', '', '61088', 'Worker electrocuted when aerial lift contacted power line.']
# ['2016', '11', '6', '', '', '21403', 'Worker died from carbon monoxide exposure.']
# ['2016', '11', '5', '', '', '91006', 'Worker killed in fall from ladder.']
# ['2016', '11', '5', '', '', '21224', 'Worker fatally crushed by bundle of rebar.']
# ['2016', '11', '4', '', '', '92270', 'Worker killed in fall from ladder.']
# ['2016', '11', '4', '', '', '77640', 'Worker asphyxiated while cleaning chemical tank trailer.']
# ['2016', '11', '4', '', '', '12827', 'Worker drowned after falling into water when scaffold collapsed.']
# ['2016', '11', '4', '', '', '90712', 'Worker fatally injured while welding inside tank.']
# ['2016', '11', '4', '', '', '48342', 'Worker killed in fall from scaffold.']
# ['2016', '11', '4', '', '', '55066', 'Worker killed after striking windshield of skid loader.']
# ['2016', '11', '3', '', '', '33701', 'Worker killed in fall down stairwell.']
# ['2016', '11', '3', '', '', '53110', 'Worker struck and killed by piece of metal while trying to unjam forging hammer.']
# ['2016', '11', '3', '', '', '45103', 'Worker killed in fall from tree.']
# ['2016', '11', '3', '', '', '98832', 'Worker died after ATV hit ditch.']
# ['2016', '11', '2', '', '', '31407', 'Worker killed in fall from ladder.']
# ['2016', '11', '1', '', '', '83401', 'Worker struck and killed by dump truck.']
# ['2016', '11', '1', '', '', '49423', 'Worker fatally crushed when gravel shaker flipped over.']
# ['2016', '11', '1', '', '', '26415', 'Worker struck and killed by falling tree branch.']
# ['2016', '11', '1', '', '', '87401', 'Worker fatally crushed by tractor.']
# ['2016', '10', '31', '', '', '93727', "Worker fatally shot when coworker's firearm discharged while being holstered."]
# ['2016', '10', '31', '', '', '02370', 'Worker fatally crushed between tractor trailer and loading dock.']
# ['2016', '10', '31', '', '', '35080', 'One worker killed and three severely injured in pipeline explosion.']
# ['2016', '10', '31', '', '', '33324', 'Worker killed in fall from aerial lift.']
# ['2016', '10', '30', '', '', '36752', 'Three workers hospitalized after suffering chemical burns.']
# ['2016', '10', '29', '', '', '23523', 'Three workers hospitalized after hose ruptured during hot oil flushing of hydraulic system.']
# ['2016', '10', '28', '', '', '48348', 'Two workers drowned while removing buoys from lake.']
# ['2016', '10', '28', '', '', '08512', 'Worker fatally crushed by equipment being loaded onto flatbed trailer.']
# ['2016', '10', '28', '', '', '79772', 'Worker killed after being pulled into loading machine by conveyor belt.']
# ['2016', '10', '28', '', '', '49014', 'Worker struck and killed by man basket.']
# ['2016', '10', '27', '', '', '41045', 'Worker struck and killed by forklift.']
# ['2016', '10', '26', '', '', '60185', 'Worker killed in fall from tanker.']
# ['2016', '10', '26', '', '', '07446', 'Worker struck and killed by falling tree limb.']
# ['2016', '10', '26', '', '', '24558', 'Worker struck and killed by tree limb.']
# ['2016', '10', '26', '', '', '17853', 'Worker struck and killed by log that fell from forklift.']
# ['2016', '10', '26', '', '', '11235', 'Worker drowned in water channel.']
# ['2016', '10', '25', '', '', '75069', 'Worker in bucket truck electrocuted after contacting power lines.']
# ['2016', '10', '25', '', '', '15108', 'Worker killed in fall from ladder.']
# ['2016', '10', '25', '', '', '55449', 'Worker struck and killed by large tubing during unloading.']
# ['2016', '10', '25', '', '', '77041', 'Worker fatally crushed when truck jumped off automotive lift.']
# ['2016', '10', '25', '', '', '89134', 'Worker fatally crushed under all-terrain spreader.']
# ['2016', '10', '25', '', '', '81650', 'Worker struck and killed by skid.']
# ['2016', '10', '24', '', '', '33019', 'One worker killed in fall and another hospitalized when scaffold collapsed.']
# ['2016', '10', '24', '', '', '69169', 'Worker struck and killed by bulkhead tube.']
# ['2016', '10', '24', '', '', '38019', 'Worker struck and killed by cotton bale loader.']
# ['2016', '10', '24', '', '', '01850', 'Worker killed in fall from ladder.']
# ['2016', '10', '24', '', '', '30182', 'Worker killed in trench collapse.']
# ['2016', '10', '22', '', '', '48809', 'Worker on crate changing light bulb killed in fall.']
# ['2016', '10', '22', '', '', '79772', 'Worker struck and killed by pipe.']
# ['2016', '10', '22', '', '', '11786', 'Worker hooking vehicle to tow truck struck and killed by another vehicle.']
# ['2016', '10', '21', '', '', '38301', 'Worker struck and killed by forklift.']
# ['2016', '10', '21', '', '', '48089', 'Worker fatally crushed while backing up a boom-type aerial lift.']
# ['2016', '10', '21', '', '', '77554', 'Worker killed when track-hoe fell over and cab filled with grout.']
# ['2016', '10', '21', '', '', '93637', 'Worker struck and killed by motor vehicle.']
# ['2016', '10', '21', '', '', '79918', 'Worker died after falling and striking head on ground.']
# ['2016', '10', '20', '', '', '71480', 'Worker killed in fall from aerial lift.']
# ['2016', '10', '20', '', '', '44691', 'Worker killed in fall inside silo.']
# ['2016', '10', '20', '', '', '37037', 'Worker struck and killed by motor vehicle.']
# ['2016', '10', '19', '', '', '19522', 'Worker electocuted by transformer.']
# ['2016', '10', '19', '', '', '38829', 'Worker fatally crushed between arm amd frame of pipe stacker machine.']
# ['2016', '10', '19', '', '', '12302', 'Two workers killed and another hospitalized following explosion at asphalt site.']
# ['2016', '10', '18', '', '', '71106', 'Worker struck and killed by dump truck.']
# ['2016', '10', '18', '', '', '53223', 'Worker killed in fall from ladder.']
# ['2016', '10', '18', '', '', '12834', 'Worker fatally crushed by metal box that fell from forklift.']
# ['2016', '10', '18', '', '', '33441', 'Worker cleaning debris on shoulder of road struck and killed by vehicle.']
# ['2016', '10', '18', '', '', '95012', 'Worker fatally crushed between tractor and harvest machine.']
# ['2016', '10', '17', '', '', '65109', 'Worker fatally crushed between arm and side of pumper truck.']
# ['2016', '10', '17', '', '', '42141', 'Worker fatally trampled by cow.']
# ['2016', '10', '17', '', '', '40601', 'Worker electrocuted while servicing mold machine.']
# ['2016', '10', '17', 'TN', '', '37914', 'Worker fatally injured in explosion while repairing trailer lights.']
# ['2016', '10', '17', '', '', '48444', 'Worker fatally crushed between trash bin and compactor.']
# ['2016', '10', '17', '', '', '47274', 'Worker struck and killed by tree limb.']
# ['2016', '10', '17', '', '', '95030', 'Worker died after being struck by resident.']
# ['2016', '10', '16', '', '', '78343', 'Worker struck and killed by load that fell from truck.']
# ['2016', '10', '16', '', '', '30144', 'Worker killed in fall from trailer.']
# ['2016', '10', '15', '', '', '07410', 'Worker killed in fall from roof.']
# ['2016', '10', '14', '', '', '95334', 'Worker killed in fall from roof.']
# ['2016', '10', '14', '', '', '40601', 'Worker struck and killed by part of mold machine.']
# ['2016', '10', '14', '', '', '33033', 'Worker struck and killed by front end loader.']
# ['2016', '10', '14', '', '', '07608', 'Worker killed in fall from roof.']
# ['2016', '10', '13', '', '', '49107', 'Worker died after slipping and falling.']
# ['2016', '10', '13', '', '', '42376', 'Worker fatally crushed between two trucks.']
# ['2016', '10', '13', '', '', '11566', 'Worker killed in fall from scaffold.']
# ['2016', '10', '12', '', '', '26038', 'Worker killed in fall through roof.']
# ['2016', '10', '12', '', '', '46342', 'Worker performing paving operations struck and killed by motor vehicle.']
# ['2016', '10', '12', '', '', '84092', 'Worker killed when mini excavator rolled over.']
# ['2016', '10', '12', '', '', '38152', 'Worker struck and killed by tree limb.']
# ['2016', '10', '11', '', '', '20906', 'Worker killed in fall from ladder.']
# ['2016', '10', '11', '', '', '85043', 'Worker on loading dock struck and killed by semi-truck.']
# ['2016', '10', '11', '', '', '30292', 'Worker fatally crushed by paving truck.']
# ['2016', '10', '11', '', '', '19020', 'Worker killed when freestanding masonry block wall collapsed.']
# ['2016', '10', '11', '', '', '12010', 'Worker killed in fall from roof.']
# ['2016', '10', '11', '', '', '11217', 'Worker struck and killed by hook that broke off crawler drill.']
# ['2016', '10', '10', '', '', '51503', 'Worker killed when enthanol ignited during transfer to tanker.']
# ['2016', '10', '10', '', '', '32174', 'Worker fatally crushed by rolling tree trunk.']
# ['2016', '10', '10', '', '', '33316', 'Worker operating golf cart struck and killed by tractor trailer.']
# ['2016', '10', '8', '', '', '56710', 'Worker killed in trench collapse.']
# ['2016', '10', '8', '', '', '78639', 'Worker repairing a concrete culvert fell into lake and drowned.']
# ['2016', '10', '8', '', '', '59270', 'Worker killed in fall from outrigger.']
# ['2016', '10', '8', '', '', '88256', 'Worker struck and killed by well casing.']
# ['2016', '10', '8', '', '', '92154', 'Worker struck and killed by semi-truck.']
# ['2016', '10', '7', '', '', '84043', 'Worker died after being buried in fill dirt at excavation site.']
# ['2016', '10', '7', '', '', '55447', 'Worker killed in fall from roof.']
# ['2016', '10', '6', '', '', '50314', 'Worker killed in fall from ladder.']
# ['2016', '10', '6', '', '', '11749', 'Worker struck and killed by payloader.']
# ['2016', '10', '6', '', '', '71203', 'Worker died of carbon monoxide exposure from jackhammer.']
# ['2016', '10', '6', '', '', '24426', 'Worker was struck and killed by door.']
# ['2016', '10', '5', '', '', '32212', 'Worker killed in fall through ceiling.']
# ['2016', '10', '5', '', '', '77978', 'Six workers severely injured from chlorine inhalation when tubing became disconnected.']
# ['2016', '10', '5', '', '', '38037', 'Worker killed in trench collapse.']
# ['2016', '10', '5', '', '', '84790', 'Worker struck and killed by glass load.']
# ['2016', '10', '5', '', '', '95677', 'Worker fatally crushed when trailer rolled off block.']
# ['2016', '10', '5', '', '', '78629', 'Five workers servicing well head hospitalized after being severely injured by flash fire.']
# ['2016', '10', '4', '', '', '77038', 'Worker fatally crushed by vehicle during servicing.']
# ['2016', '10', '3', '', '', '30642', 'Worker fatally crushed when sprayer overtuned.']
# ['2016', '10', '3', '', '', '60466', 'Worker struck and killed by pipes that fell from truckbed during unloading.']
# ['2016', '10', '3', '', '', '85301', 'Worker electrocuted while installing grounding wire through switch box.']
# ['2016', '10', '3', '', '', '95823', 'Worker fatally crushed between trash dumpsters.']
# ['2016', '10', '3', '', '', '77019', 'Worker killed in fall from scaffold.']
# ['2016', '10', '3', '', '', '75165', 'Two workers on side of road struck and killed by tractor trailer truck.']
# ['2016', '10', '3', '', '', '49087', 'Worker trimming tree akilled in fall.']
# ['2016', '10', '3', '', '', '77060', 'Worker struck and killed by vehicle.']
# ['2016', '10', '3', '', '', '40177', 'Worker struck and killed bymotor vehicle.']
# ['2016', '9', '30', '', '', '84003', 'Worker killed in trench collapse.']
# ['2016', '9', '29', '', '', '49455', 'Worker worker struck and killed by falling bushel bins.']
# ['2016', '9', '26', '', '', '37075', 'Worker killed in fall through window opening.']
# ['2016', '9', '26', '', '', '99155', 'Worker struck and killed by tree top.']
# ['2016', '9', '26', '', '', '47946', 'Killed in grain elevator explosion.']
# ['2016', '9', '23', '', '', '92407', 'Worker killed in fall from ladder.']
# ['2016', '9', '22', '', '', '56058', 'Worker killed in fall from top of waste tanker.']
# ['2016', '9', '17', '', '', '94062', 'Worker fatally crushed when lift tipped off curb.']
# ['2016', '9', '15', '', '', '50703', 'Worker died after being struck by chain.']
# ['2016', '9', '14', '', '', '90631', 'Worker killed in fall from scaffold.']
# ['2016', '9', '2', '', '', '88310', 'Worker fatally shot by suspect during foot pursuit.']
# ['2016', '8', '23', '', '', '91710', 'Worker killed in fall from scaffold.']
# ['2016', '8', '16', '', '', '48104', 'Worker died in fall from roof.']
# ['2016', '7', '19', '', '', '48322', 'Worker killed in fall through stair hole.']
# ['2016', '6', '27', '', '', '87061', 'Worker died from hantavirus after being exposed to mouse droppings while cleaning cabins.']
# ['2016', '5', '24', '', '', '42437', 'Worker struck and killed by falling tree.']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-5abd7d67046b> in <module>
#      54
#      55     m = split_date[0]
# ---> 56     d = split_date[1]
#      57     y = split_date[2]
#      58     ed = old_osha[i][3]
#
# IndexError: list index out of range

# %%
#OSHA DATA
import csv
import copy

#Import old osha dataset and convert into a list of lists
csv_data_read = open('old_osha.csv', 'rt')
old_osha = list(csv.reader(csv_data_read))
csv_data_read.close()

#Import new osha dataset and convert into a list of lists
csv_data_read = open('new_osha.csv', 'rt')
new_osha = list(csv.reader(csv_data_read))
csv_data_read.close()

#Create a list of state abbreviations
states = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA",
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

#Create "osha" to be the combination of both datasets and convert to csv
osha = []

#Dictionary used to build out each row of the osha dataset, values are instantiated as blank strings
row_build = {'year':'', 'month':'', 'day':'', 'state':'', 'city':'', 'zip':'', 'event':''}

#Parse each row of the new osha data and separate field values
#Note: This dataset does not have zip code information
for i in range(1,):

    row = copy.copy(row_build)

    #Split the date column into day, month and year and add them to the row dictionary
    split_date = new_osha[i][0].split('/')
    row['month'] = split_date[0]
    row['day'] = split_date[1]
    row['year'] = split_date[2]

    #Select city, state, and event description information and add them to the row dictionary
    row['state'] = new_osha[i][2]
    row['city'] = new_osha[i][1]
    row['event'] = new_osha[i][3]

    #append new row to osha dataset using values from the row dictionary
    osha.append([row['year'], row['month'], row['day'], row['state'], row['city'], row['zip'], row['event']])

print(osha)

it = input("End: ")
# Out:
# [['2020', '5', '16', 'IL', 'East Moline', '', 'Worker died from injury suffered after trippijng and falling.'], ['2020', '5', '7', 'TN', 'Goodlettsville', '', 'Worker fatally struck by vehicle.'], ['2020', '4', '24', 'UT', 'Salina', '', 'Worker died in fall from scaffold.'], ['2020', '4', '23', 'UT', 'Saint George', '', 'Worker died in fall from roof.'], ['2020', '4', '22', 'OH', 'Logan', '', 'Worker fatally struck by falling tree.'], ['2020', '4', '7', 'TN', 'Knoxville', '', 'Three workers fatally stabbed by customer.'], ['2020', '4', '2', 'ID', 'Kuna', '', 'Worker died from infection of occupational injury.'], ['2020', '4', '2', 'OH', 'Elyria', '', 'Worke died in fall through floor opening.'], ['2020', '4', '1', 'TN', 'Nashville', '', 'Worker electrocuted while fixing lights.'], ['2020', '3', '27', 'NY', 'Massapequa', '', 'Worker died in vehicle collision.'], ['2020', '3', '22', 'WI', 'Darien', '', 'Worker died in fall down stairs.'], ['2020', '3', '20', 'RI', 'Providence', '', 'Worker electrocuted when ladder contacted power line.'], ['2020', '3', '18', 'TX', 'El Paso', '', 'Worker died in fall from ladder.'], ['2020', '3', '17', 'IL', 'Melrose Park', '', 'Worker died in fall from ladder.'], ['2020', '3', '16', 'OH', 'Millersburg', '', 'Worker fatally struck by rolling logs.'], ['2020', '3', '16', 'FL', 'Miami Beach', '', 'Worker ftally struck by vehicle.'], ['2020', '3', '13', 'TN', 'Memphis', '', 'Worker died from inhalation of muriatic acid.'], ['2020', '3', '12', 'NJ', 'Teterboro', '', 'Worker suffered fatal injury in fall while loading luggage onto airplane.'], ['2020', '3', '12', 'TX', 'Spring', '', 'Worker died in fall from roof after receiving electric shock.'], ['2020', '3', '10', 'UT', 'Brigham City', '', 'Worker died when oxygen cylinder exploded.'], ['2020', '3', '10', 'IL', 'Mc Cook', '', 'Worker was fatally struck by hydraulic ram.'], ['2020', '3', '9', 'TN', 'Moss', '', 'Worker fatally crushed under excavator.'], ['2020', '3', '6', 'TX', 'Houston', '', 'Worker fatally struck by vehicle.'], ['2020', '3', '5', 'TX', 'Fritch', '', 'Worker fatally crushed between excavator bucket and trench wall.'], ['2020', '3', '3', 'TN', 'Mount Juliet', '', 'Worker died in collapse of building struck by tornado.'], ['2020', '3', '2', 'TX', 'Dallas', '', 'Worker fatally crushed by rolling tractor.'], ['2020', '3', '1', 'GA', 'Social Circle', '', 'Worker fatally struck by falling crane load.'], ['2020', '2', '29', 'WI', 'Wisconsin Rapids', '', 'Worker died in fall from paper mill building.'], ['2020', '2', '28', 'TX', 'Houston', '', 'Worker died after being struck by resident'], ['2020', '2', '28', 'OR', 'Wilsonville', '', 'Worker fatally struck by falling pallet.'], ['2020', '2', '22', 'TX', 'Port Neches', '', 'Worker died in fall down metal stairway.'], ['2020', '2', '22', 'CA', 'Whittier', '', 'Worker fatally shot during robbery.'], ['2020', '2', '20', 'OK', 'Oklahoma City', '', 'Worker died when scissor lift tipped over.'], ['2020', '2', '19', 'TN', 'Chattanooga', '', 'Worker died from complicatons of surgery for workplace injury.'], ['2020', '2', '18', 'WI', 'Prentice', '', 'Worker fatally struck by snow plow.'], ['2020', '2', '17', 'GA', 'Macon', '', 'Worker died in fall from deck.'], ['2020', '2', '17', 'OK', 'Purcell', '', 'Worker fatally struck by truck when brakes failed.'], ['2020', '2', '17', 'MD', 'Druid', '', 'Worker fatally crushed by rolling truck.'], ['2020', '2', '17', 'OH', 'Thornville', '', 'Worker died in trench collapse.'], ['2020', '2', '17', 'KS', 'Olathe', '', 'Worker fatally stuck by trailer.'], ['2020', '2', '16', 'FL', 'Miami', '', 'Worker fatally struck be vehicle involved in collision.'], ['2020', '2', '14', 'NC', 'Hendersonville', '', 'Worker fatally struck by refuse truck.'], ['2020', '2', '13', 'NY', 'Albany', '', 'Worker died in fall from scaffolding.'], ['2020', '2', '13', 'MI', 'Fairview', '', 'Worker died after becoming caught in conveyor belt.'], ['2020', '2', '13', 'TX', 'Sherman', '', 'Wor ...
